# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv('Batsman_All - Copy.csv')
df.head()
# Out:
#          Player       Span  Mat  Inns  NO  Runs  HS    Ave    BF      SR  \
# 0  Abdur Razzak  2004-2014  153    97  39   779  53  13.43  1020   76.37
# 1    Abul Hasan  2012-2018    7     3   0    11   7   3.66    16   68.75
# 2     Abu Hider  2018-2018    2     1   0     1   1   1.00    11    9.09
# 3  Afif Hossain  2020-2020    1     1   0     7   7   7.00     4  175.00
# 4   Aftab Ahmed  2004-2010   85    85   6  1954  92  24.73  2353   83.04
#
#    hundred  fifty  zero  four  six
# 0        0      1    12    55   21
# 1        0      0     0     1    0
# 2        0      0     0     0    0
# 3        0      0     0     1    0
# 4        0     14     8   205   49

# %%
df.describe()
# Out:
#               Mat        Inns          NO         Runs          HS  \
# count  128.000000  128.000000  128.000000   128.000000  128.000000
# mean    32.343750   27.492188    4.453125   545.921875   41.562500
# std     47.795074   42.373479    7.804561  1163.277779   41.087912
# min      1.000000    1.000000    0.000000     0.000000    0.000000
# 25%      3.000000    2.000000    0.000000    11.750000    8.000000
# 50%     12.000000   10.000000    1.000000    74.000000   26.500000
# 75%     39.500000   30.250000    5.000000   499.000000   62.250000
# max    218.000000  205.000000   42.000000  7202.000000  176.000000
#
#               Ave           BF          SR     hundred       fifty  \
# count  128.000000   128.000000  128.000000  128.000000  128.000000
# mean    14.623828   779.023438   56.101484    0.445312    2.812500
# std     10.946962  1509.440140   29.623658    1.663923    7.525024
# min      0.000000     1.000000    0.000000    0.000000    0.000000
# 25%      5.045000    24.000000   37.942500    0.000000    0.000000
# 50%     13.355000   134.500000   55.690000    0.000000    0.000000
# 75%     22.402500   752.500000   71.277500    0.000000    2.000000
# max     42.000000  9153.000000  175.000000   13.000000   47.000000
#
#              zero        four         six
# count  128.000000  128.000000  128.000000
# mean     2.804688   50.398438    6.382812
# std      3.853741  111.148432   15.194861
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      1.000000    6.000000    0.000000
# 75%      4.000000   46.500000    4.250000
# max     18.000000  783.000000   91.000000

# %%
df['rating'] = df['Runs'] / df['Inns'] + df['Runs'] / df['BF'] + df['hundred'] + df['fifty'] / df['Inns'] + df['four']*4 / df['Inns']

# %%
df['rating'] = df['Runs'] / df['Inns'] + df['Runs'] / df['BF'] + df['hundred'] + df['fifty'] / df['Inns'] + df['four']*4 / df['Inns'] + df['six']*6 / df['Inns']+ df['zero']/ df['Inns']

# %%
mn.head(5)
# Out:
# 0    13.114241
# 1     5.687500
# 2     1.090909
# 3    12.750000
# 4    37.653959
# dtype: float64

# %%
df.head()
# Out:
#          Player       Span  Mat  Inns  NO  Runs  HS    Ave    BF      SR  \
# 0  Abdur Razzak  2004-2014  153    97  39   779  53  13.43  1020   76.37
# 1    Abul Hasan  2012-2018    7     3   0    11   7   3.66    16   68.75
# 2     Abu Hider  2018-2018    2     1   0     1   1   1.00    11    9.09
# 3  Afif Hossain  2020-2020    1     1   0     7   7   7.00     4  175.00
# 4   Aftab Ahmed  2004-2010   85    85   6  1954  92  24.73  2353   83.04
#
#    hundred  fifty  zero  four  six     rating
# 0        0      1    12    55   21  12.495684
# 1        0      0     0     1    0   5.687500
# 2        0      0     0     0    0   1.090909
# 3        0      0     0     1    0  12.750000
# 4        0     14     8   205   49  37.183370

# %%
df['res'] = df['rating'].apply(lambda x: '1' if x >= 20 else '0')

# %%
df.head()
# Out:
#          Player       Span  Mat  Inns  NO  Runs  HS    Ave    BF      SR  \
# 0  Abdur Razzak  2004-2014  153    97  39   779  53  13.43  1020   76.37
# 1    Abul Hasan  2012-2018    7     3   0    11   7   3.66    16   68.75
# 2     Abu Hider  2018-2018    2     1   0     1   1   1.00    11    9.09
# 3  Afif Hossain  2020-2020    1     1   0     7   7   7.00     4  175.00
# 4   Aftab Ahmed  2004-2010   85    85   6  1954  92  24.73  2353   83.04
#
#    hundred  fifty  zero  four  six     rating res
# 0        0      1    12    55   21  12.495684   0
# 1        0      0     0     1    0   5.687500   0
# 2        0      0     0     0    0   1.090909   0
# 3        0      0     0     1    0  12.750000   0
# 4        0     14     8   205   49  37.183370   1

# %%
target=df.res
inputs=df.drop(['res','Player','Span','rating'],axis='columns')

# %%
X_train, X_test, y_train, y_test= train_test_split(inputs,target,test_size=0.3)

# %%
model = GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.8974358974358975

# %%
y_test[:5]
# Out:
# 34    0
# 72    0
# 96    0
# 23    0
# 13    0
# Name: res, dtype: object

# %%
model.predict(X_test[:5])
# Out:
# array(['0', '0', '0', '0', '0'], dtype='<U1')

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[0.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 1.11467758e-10],
#        [9.99990678e-01, 9.32203605e-06],
#        [2.98402792e-07, 9.99999702e-01],
#        [9.99999972e-01, 2.78595467e-08],
#        [2.55218534e-12, 1.00000000e+00],
#        [9.58042415e-27, 1.00000000e+00],
#        [1.00000000e+00, 4.69895443e-10],
#        [9.99999942e-01, 5.83865267e-08],
#        [6.77421818e-69, 1.00000000e+00]])

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(GaussianNB(),X_train, y_train, cv=5)
# Out:
# array([0.77777778, 0.94444444, 0.94444444, 0.94444444, 0.76470588])

# %%
dm = pd.read_csv('Batsman_Current - Copy.csv')

# %%
dm['rating'] = dm['Runs'] / dm['Inns'] + dm['Runs'] / dm['BF'] + dm['hundred'] + dm['fifty'] / dm['Inns'] + dm['four']*4 / dm['Inns'] + dm['six']*6 / dm['Inns']+ df['zero'] / df['Inns']

# %%
p=dm.drop(['Player','Span','rating'],axis='columns')

# %%
dm.head(10)
# Out:
#                Player       Span  Mat  Inns  NO  Runs   HS    Ave    BF  \
# 0        Afif Hossain  2020-2020    1     1   0     7    7   7.00     4
# 1     Al-Amin Hossain  2014-2020   15     7   5     4    2   2.00    20
# 2        Anamul Haque  2012-2019   38    52   0  1052  120  30.05  1488
# 3           Liton Das  2015-2020   36    36   3  1079  176  32.69  1133
# 4         Mahmudullah  2007-2020  188   163  42  4070  128  33.63  5311
# 5    Mashrafe Mortaza  2001-2020  218   156  28  1773   51  13.85  2021
# 6  Mehidy Hasan Miraz  2017-2020   41    26   4   393   51  17.86   508
# 7     Mohammad Mithun  2014-2020   27    23   3   575   63  28.75   718
# 8  Mohammad Saifuddin  2017-2020   22    13   4   290   51  32.22   337
# 9    Mosaddek Hossain  2016-2019   35    30  10   549   52  27.45   633
#
#        SR  hundred  fifty  zero  four  six     rating
# 0  175.00        0      0     0     1    0  12.873711
# 1   20.00        0      0     2     0    0   0.771429
# 2   70.69        3      3     6   103   19  34.110835
# 3   95.23        3      3     4   113   22  50.230117
# 4   76.63        3     21     8   317   57  38.835912
# 5   87.72        0      1    15   150   62  18.479853
# 6   77.36        0      1     0    39    4  22.918727
# 7   80.08        0      5     1    49   14  38.267898
# 8   86.05        0      2     1    24    6  33.761633
# 9   86.72        0      2     1    53   11  28.707528

# %%
model.predict(p[:10])
# Out:
# array(['0', '0', '1', '1', '1', '1', '0', '1', '1', '1'], dtype='<U1')

# %%
pre = dm['rating'].apply(lambda x: '1' if x >= 20 else '0')

# %%
pre.head(10)
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# 6    1
# 7    1
# 8    1
# 9    1
# Name: rating, dtype: object

# %%
s=dm.sort_values(by='rating', ascending=False)

# %%
s.head(6)
# Out:
#              Player       Span  Mat  Inns  NO  Runs   HS    Ave    BF     SR  \
# 19      Tamim Iqbal  2007-2020  207   205   9  7202  158  36.74  9153  78.68
# 16  Shakib Al Hasan  2006-2019  206   194  27  6323  134  37.86  7641  82.75
# 17    Soumya Sarkar  2014-2019   55    54   3  1728  127  33.88  1753  98.57
# 10  Mushfiqur Rahim  2006-2020  218   204  34  6174  144  36.31  7794  79.21
# 3         Liton Das  2015-2020   36    36   3  1079  176  32.69  1133  95.23
# 4       Mahmudullah  2007-2020  188   163  42  4070  128  33.63  5311  76.63
#
#     hundred  fifty  zero  four  six     rating
# 19       13     47    18   783   91  67.339285
# 16        9     47    10   574   42  55.887491
# 17        2     11     5   200   42  54.828819
# 10        7     38    10   492   82  50.430157
# 3         3      3     4   113   22  50.230117
# 4         3     21     8   317   57  38.835912

# %%
k=s.Player

# %%
k.head(6)
# Out:
# 19        Tamim Iqbal
# 16    Shakib Al Hasan
# 17      Soumya Sarkar
# 10    Mushfiqur Rahim
# 3           Liton Das
# 4         Mahmudullah
# Name: Player, dtype: object
